# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=[27,9])

# Your plotting code here
x1 = np.linspace(0, 8*2*np.pi, 1000)
x2 = np.linspace(0, 8*2*np.pi, 1000)
y_zero = np.zeros(np.shape(x1))

plt.plot(x1, np.sin(x1), 'k', lw=5)
#plt.plot(x2, np.sin(x2/8), '#702963', lw=5)
plt.plot(x1, y_zero, 'grey', ls = '--', lw=3)

# Remove all axes
ax.set_axis_off()

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=[27,9])

# Your plotting code here
x1 = np.linspace(0, 8*2*np.pi, 1000)
x2 = np.linspace(0, 8*2*np.pi, 1000)
y_zero = np.zeros(np.shape(x1))

plt.plot(x1, np.sin(x1), 'k', lw=5)
plt.plot(x2, -np.sin(x2/8), '#702963', lw=5)
plt.plot(x1, y_zero, 'grey', ls = '--', lw=3)


plt.axvline(1*8*2*np.pi/9)
plt.axvline(2*8*2*np.pi/9)
plt.axvline(3*8*2*np.pi/9)
plt.axvline(4*8*2*np.pi/9)
plt.axvline(5*8*2*np.pi/9)
plt.axvline(6*8*2*np.pi/9)
plt.axvline(7*8*2*np.pi/9)
plt.axvline(8*8*2*np.pi/9)
plt.axvline(9*8*2*np.pi/9)

# Remove all axes
ax.set_axis_off()
